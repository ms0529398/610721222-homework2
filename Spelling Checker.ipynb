# %%
def distance(s1, s2):
    m=len(s1)+1
    n=len(s2)+1

    tbl = {}
    for i in range(m): tbl[i,0]=i
    for j in range(n): tbl[0,j]=j
    for i in range(1, m):
    for j in range(1, n):
        cost = 0 if s1[i-1] == s2[j-1] else 1
        tbl[i,j] = min(tbl[i, j-1]+1, tbl[i-1, j]+1, tbl[i-1, j-1]+cost)

    return tbl[i,j]

# %%
inputs = input("Please enter a string: ")
string = inputs.strip()
file = open("dictionary.txt",'r')
all_line = file.readlines()
decide=1
# Out:
# Please enter a string: aaa

# %%
for line in all_line:
     if distance(string,line.strip())==0:
        print("Entered correctly",string)
        print("In the dictionary:",line)
            decide=0

# %%
if decide==1:
    for line in all_line:
    if distance(string,line.strip())<=2:
        print("Similar word: ",line.strip()," distance: ",distance(string,line.strip()))
# Out:
# Similar word:  a  distance:  2
# Similar word:  abc  distance:  2
# Similar word:  ace  distance:  2
# Similar word:  act  distance:  2
# Similar word:  ad  distance:  2
# Similar word:  Ada  distance:  2
# Similar word:  add  distance:  2
# Similar word:  ado  distance:  2
# Similar word:  afar  distance:  2
# Similar word:  aft  distance:  2
# Similar word:  agar  distance:  2
# Similar word:  age  distance:  2
# Similar word:  ago  distance:  2
# Similar word:  ah  distance:  2
# Similar word:  aid  distance:  2
# Similar word:  ail  distance:  2
# Similar word:  aim  distance:  2
# Similar word:  air  distance:  2
# Similar word:  ajar  distance:  2
# Similar word:  ala  distance:  1
# Similar word:  alai  distance:  2
# Similar word:  alan  distance:  2
# Similar word:  alb  distance:  2
# Similar word:  alba  distance:  2
# Similar word:  ale  distance:  2
# Similar word:  alga  distance:  2
# Similar word:  alia  distance:  2
# Similar word:  all  distance:  2
# ...
